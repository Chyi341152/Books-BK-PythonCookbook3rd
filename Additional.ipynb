# %% [markdown]
# # Python Progress Bar

# %% [markdown]
# ## 1.1. tqdm  -- Add a progress meter to your loops in a second
# tqdm means "progress" in arabic阿拉伯语

# %%
import time
from tqdm import tqdm

for i in tqdm(range(10)):
    time.sleep(i)
# Out:
# 100%|██████████| 10/10 [00:45<00:00,  4.50s/it]

# %%
# tqdm.py
__all__ = ['tqdm', 'trange']

import sys
import time

def format_interval(t):
    mins, s = divmod(int(t), 60)
    h, m = divmod(mins, 60)
    if h:
        return '%d:%02d:%02d' % (h, m, s)
    else:
        return '%02d:%02d' % (m, s)

def format_meter(n, total, elapsed, n_bars):
    # n - number of finished iterations
    # total - total number of iterations, or None
    # elapsed - number of seconds passed since start
    # N_BARS = bar number
    if n > total:
        total = None
    elapsed_str = format_interval(elapsed)
    rate = '%5.2f' % (n / elapsed) if elapsed else '?'
    
    if total:
        frac = float(n) / total
        N_BARS = n_bars
        bar_length = int(frac * N_BARS)
        bar = '#' * bar_length + '-' * (N_BARS - bar_length)
        
        percentage = '%3d%%' % (frac * 100)
        
        left_str = format_interval(elapsed / n * (total - n)) if n else '?'
        
        return '|%s| %d/%d %s [elapsed: %s left: %s, %s iters/sec]' % (
            bar, n, total, percentage, elapsed_str, left_str, rate)
    
    else:
        return '%d [elapsed: %s, %s iters/sec]' % (n, elapsed_str, rate)


class StatusPrinter(object):
    def __init__(self, file):
        self.file = file
        self.last_printed_len = 0
    
    def print_status(self, s):
        self.file.write('\r' + s + ' ' * max(self.last_printed_len - len(s), 0))
        self.file.flush()
        self.last_printed_len = len(s)


def tqdm(iterable, desc='', total=None, leave=False, file=sys.stderr,
         mininterval=0.5, miniters=1, n_bars=100):
    """
    Get an iterable object, and return an iterator which acts exactly like the
    iterable, but prints a progress meter and updates it every time a value is
    requested.
    'desc' can contain a short string, describing the progress, that is added
    in the beginning of the line.
    'total' can give the number of expected iterations. If not given,
    len(iterable) is used if it is defined.
    'file' can be a file-like object to output the progress message to.
    If leave is False, tqdm deletes its traces from screen after it has
    finished iterating over all elements.
    If less than mininterval seconds or miniters iterations have passed since
    the last progress meter update, it is not updated again.
    """
    if total is None:
        try:
            total = len(iterable)
        except TypeError:
            total = None
    prefix = desc + ': ' if desc else ''
    sp = StatusPrinter(file)
    sp.print_status(prefix + format_meter(0, total, 0, n_bars))
    start_t = last_print_t = time.time()
    last_print_n = 0
    n = 0
    for obj in iterable:
        yield obj
        # Now the object was created and processed, so we can print the meter.
        n += 1
        if n - last_print_n >= miniters:
            # We check the counter first, to reduce the overhead of time.time()
            cur_t = time.time()
            if cur_t - last_print_t >= mininterval:
                sp.print_status(prefix + format_meter(n, total, cur_t - start_t, n_bars))
                last_print_n = n
                last_print_t = cur_t
    
    if not leave:
        sp.print_status('')
        sys.stdout.write('\r')
    else:
        if last_print_n < n:
            cur_t = time.time()
            sp.print_status(prefix + format_meter(n, total, cur_t - start_t, n_bars))
        file.write('\n')


def trange(*args, **kwargs):
    """A shortcut for writing tqdm(range()) on py3 or tqdm(xrange()) on py2"""
    try:
        f = xrange
    except NameError:
        f = range
    return tqdm(f(*args), **kwargs)

if __name__ == '__main__':
    for i in tqdm(range(50),n_bars=50):
        time.sleep(.1)

# %% [markdown]
# # 1.2 Beautiful Soup 4 Requests urllib
# Scrape data from websites.

# %%
from bs4 import BeautifulSoup as bs 
import urllib.request 

if __name__ == '__main__':
    list_of_most_popular_websites = 'https://en.wikipedia.org/wiki/List_of_most_popular_websites'
    source = urllib.request.urlopen(list_of_most_popular_websites)
    if source.status == 200:
        content = source.read()
        soup = bs(content, 'lxml')
        print("title of the page:", soup.title)
        print("get attributes:", soup.title.name)
        print("get values:", soup.title.string)
        print("beginning navigation:", soup.title.parent.name)
        #print("getting specific values:", soup.table)
        #print("find them all", soup.find_all('table'))
        for table in soup.find_all('table')[1:]:
            print(table.attrs)
            print(table.string) # NavigableString 对象
            print(table.text) # unicode text 
        # grab links 
        for url in soup.find_all('a'):
            print(url.get('href')) # get the true URL 
        # grab text 
        print(soup.get_text())
        
        print("nav:", soup.nav)
        
        # class_="wiki", which allows us to work with a specific class of tag
        for table in soup.find_all('table', class_='wikitable'):
            print(table.text)
            tbody = table.find('tbody')
            tr_rows = tbody.find_all('tr')
            for tr in tr_rows:
                td = tr.find_all('td')
                row = [i.text for i in td if i == 1]
                print(row)
    else:
        print('404 Not Found')
# Out:
# title of the page: <title>List of most popular websites - Wikipedia</title>
# get attributes: title
# get values: List of most popular websites - Wikipedia
# beginning navigation: head
# {'style': 'font-size:96%;', 'width': '100%', 'class': ['wikitable', 'sortable']}
# None
#
#
# Site
# Domain
# Alexa top 100 global websites
# (As of April 3, 2017[update])[3]
# SimilarWeb top 100 websites
# (As of May 2017)[4]
# Type
#
# Principal country
#
#
#
# Google
# google.com
# 1
# 1
# Internet services and products
#  U.S.
#
#
# YouTube
# youtube.com
# 2
# 3
# Video sharing
#  U.S.
#
#
# Facebook
# facebook.com
# 3
# 2
# Social network
#  U.S.
#
#
# Baidu
# baidu.com
# 4
# 11
# Search engine
#  China
#
#
# Wikipedia
# wikipedia.org
# 5
# 5
# Encyclopedia
#  U.S.
#
#
# Yahoo!
# yahoo.com
# 6
# 4
# Portal and media
#  U.S.
#
#
# Google India
# google.co.in
# 7
# 8
# Search engine
#  India
#
#
# Reddit
# reddit.com
# 8
# 27
# Social news and entertainment
#  U.S.
#
#
# Tencent QQ
# qq.com
# 9
# 36
# Portal
#  China
#
#
# Taobao
# taobao.com
# 10
# 65
# Online shopping
#  China
#
#
# Amazon
# amazon.com
# 11
# 14
# E-commerce and cloud computing
#  U.S.
#
#
# Tmall
# tmall.com
# 12
# 74
# Online shopping
#  China
#
#
# Twitter
# twitter.com
# 13
# 6
# Social network
#  U.S.
#
#
# Google Japan
# google.co.jp
# 14
# 20
# Search engine
#  Japan
#
#
# Sohu
# sohu.com
# 15
# 204
# Portal
#  China
#
#
# Windows Live
# live.com
# 16
# 7
# Software plus services
#  U.S.
#
#
# VK
# vk.com
# 17
# 12
# Social network
#  Russia
#
#
# Instagram
# instagram.com
# 18
# 15
# Photo sharing and social media
#  U.S.
#
#
# Sina Corp
# sina.com.cn
# 19
# 110
# Portal and instant messaging
#  China
#
#
# 360 Safeguard
# 360.cn
# 20
# 85
# Internet security software
#  China
#
#
# Google Germany
# google.de
# 21
# 17
# Search engine
#  Germany
#
#
# Jingdong Mall
# jd.com
# 22
# 96
# E-commerce
#  China
#
#
# Google UK
# google.co.uk
# 23
# 10
# Search engine
#  UK
#
#
# LinkedIn
# linkedin.com
# 24
# 41
# Professional Social network
#  U.S.
#
#
# Sina Weibo
# weibo.com
# 25
# 81
# Social network
#  China
#
#
# Google France
# google.fr
# 26
# 19
# Search engine
#  France
#
#
# Google Russia
# google.ru
# 27
# 23
# Search engine
#  Russia
#
#
# Google Brazil
# google.com.br
# 28
# 8
# Search engine
#  Brazil
#
#
# Yahoo! Japan
# yahoo.co.jp
# 29
# 26
# Portal
#  Japan
#
#
# Yandex
# yandex.ru
# 30
# 13
# Internet services and products
#  Russia
#
#
# Netflix
# netflix.com
# 31
# 18
# Streaming TV and movies
#  U.S.
#
#
# t.co
# t.co
# 32
# 78
# URL shortening for links on Twitter
#  U.S.
#
#
# Google Hong Kong
# google.com.hk
# 33
# 138
# Search engine
#  Hong Kong
#
#
# Hao123
# hao123.com
# 34
# 180
# Web directories
#  China
#
#
# Imgur
# imgur.com
# 35
# 57
# Image sharing
#  U.S.
#
#
# Google Italy
# google.it
# 36
# 29
# Search engine
#  Italy
#
#
# eBay
# ebay.com
# 37
# 32
# Online auctions and shopping
#  U.S.
#
#
# Pornhub
# pornhub.com
# 38
# 24
# Pornography
#  Canada
#
#
# Google Spain
# google.es
# 39
# 35
# Search engine
#  Spain
#
#
# Tmall
# detail.tmall.com
# 40
# N/A[notes 1]
# Online shopping
#  China
#
#
# WordPress.com
# wordpress.com
# 41
# 43
# Blogging and social media websites
#  U.S.
#
#
# MSN
# msn.com
# 42
# 33
# Portal
#  U.S.
#
#
# AliExpress
# aliexpress.com
# 43
# 49
# Online shopping
#  China
#
#
# Bing
# bing.com
# 44
# 40
# Search engine
#  U.S.
#
#
# Tumblr
# tumblr.com
# 45
# 44
# Social media
#  U.S.
#
#
# Google Canada
# google.ca
# 46
# 25
# Search engine
#  Canada
#
#
# LiveJasmin
# livejasmin.com
# 47
# 196
# Pornography
#  U.S.
#
#
# Microsoft
# microsoft.com
# 48
# 47
# Software and technology
#  U.S.
#
#
# Stack Overflow
# stackoverflow.com
# 49
# 93
# Question and answer site
#  U.S.
#
#
# Twitch
# twitch.tv
# 50
# 76
# Streaming primarily video games
#  U.S.
#
#
# Soso.com
# soso.com
# 51
# 98,882
# Search engine
#  China
#
#
# Blogspot
# blogspot.com
# 52
# 450,370
# Blogging
#  U.S.
#
#
# Amazon Japan
# amazon.co.jp
# 53
# 71
# E-commerce
#  Japan
#
#
# Odnoklassniki
# ok.ru
# 54
# 28
# Social Networking
#  Russia
#
#
# Google Mexico
# google.com.mx
# 55
# 30
# Search Engine
#  Mexico
#
#
# Apple Inc.
# apple.com
# 56
# 67
# Technology and software
#  U.S.
#
#
# Naver
# Naver.com
# 57
# 59
# Portal
#  Korea
#
#
# Mail.ru
# mail.ru
# 58
# 16
# Portal
#  Russia
#
#
# IMDb
# imdb.com
# 59
# 51
# Film, TV show, and video game database
#  U.S.
#
#
# PopAds
# popads.net
# 60
# N/A[notes 1]
# Pop-up advertising
#  Costa Rica
#
#
# Tianya Club
# tianya.cn
# 61
# 730
# Internet forum
#  China
#
#
# Microsoft Office
# office.com
# 62
# 48
# Online office suite
#  U.S.
#
#
# Google Korea
# google.co.kr
# 63
# 177
# Search Engine
#  Korea
#
#
# GitHub
# github.com
# 64
# 74
# Source code hosting service
#  U.S.
#
#
# Pinterest
# pinterest.com
# 65
# 39
# Social media
#  U.S.
#
#
# PayPal
# paypal.com
# 66
# 64
# Payment system
#  U.S.
#
#
# Diply
# diply.com
# 67
# 588
# Entertainment
#  Canada
#
#
# Google Taiwan
# google.com.tw
# 68
# 81
# Search engine
#  Taiwan
#
#
# Google Turkey
# google.com.tr
# 69
# 22
# Search engine
#  Turkey
#
#
# Google Australia
# google.com.au
# 70
# 42
# Search Engine
#  Australia
#
#
# Amazon Germany
# amazon.de
# 72
# 75
# E-commerce
#  Germany
#
#
# Google Indonesia
# google.co.id
# 73
# 38
# Search engine
#  Indonesia
#
#
# Microsoft Online Services
# microsoftonline.com
# 74
# 60
# Software as a service
#  U.S.
#
#
# Onclckds
# onclckds.com
# 75
# N/A[notes 1]
# Online advertising network
#  U.S.
#
#
# Amazon UK
# amazon.co.uk
# 76
# 76
# E-commerce
#  UK
#
#
# TXXX
# txxx.com
# 77
# N/A[notes 1]
# Pornography
#  U.S.
#
#
# Adobe Systems
# adobe.com
# 78
# 94
# Software
#  U.S.
#
#
# Wikia
# wikia.com
# 79
# 66
# Wikis
#  U.S.
#
#
# CNZZ
# cnzz.com
# 80
# 42,424
# Web traffic statistics
#  China
#
#
# xHamster
# xhamster.com
# 81
# 46
# Pornography
#  U.S.
#
#
# Cốc Cốc
# coccoc.com
# 82
# 342
# Search engine and web browser
#  Vietnam
#
#
# Bonga Cams
# bongacams.com
# 83
# 230
# Pornography
#  Russia
#
#
# FC2
# fc2.com
# 84
# 82
# Portal
#  Japan
#
#
# Pixnet
# pixnet.net
# 85
# 322
# Social network, photo sharing, blogging
#  Taiwan
#
#
# Google Poland
# google.pl
# 86
# 37
# Search engine
#  Poland
#
#
# Dropbox
# dropbox.com
# 87
# 72
# File hosting service
#  U.S.
#
#
# Google file storage
# googleusercontent.com
# 88
# N/A[notes 1]
# File hosting service
#  U.S.
#
#
# Guangming Daily
# gmw.cn
# 89
# 15,520
# Newspaper
#  China
#
#
# WhatsApp
# whatsapp.com
# 91
# 34
# Instant messaging
#  U.S.
#
#
# Google Egypt
# google.com.eg
# 93
# 87
# Search engine
#  Egypt
#
#
# Google Thailand
# google.co.th
# 94
# 62
# Search engine
#  Thailand
#
#
# Google Saudi Arabia
# google.com.sa
# 95
# N/A[notes 1]
# Search engine
#  Saudi Arabia
#
#
# Amazon India
# amazon.in
# 98
# 121
# E-commerce
#  India
#
#
# Google Argentina
# google.com.ar
# 101
# 53
# Search engine
#  Argentina
#
#
# BBC
# bbc.co.uk
# 104
# 55
# UK public broadcasting
#  UK
#
#
# Craigslist
# craigslist.org
# 105
# 52
# Classified advertising
#  U.S.
#
#
# BBC Online
# bbc.com
# 109
# 89
# Global News
#  UK
#
#
# Soundcloud
# soundcloud.com
# 112
# 94
# Streaming media
#  U.S.
#
#
# Google Netherlands
# google.nl
# 113
# 54
# Search engine
#  Netherlands
#
#
# XVideos
# xvideos.com
# 117
# 21
# Pornography
#  France
#
#
# Booking.com
# booking.com
# 123
# 73
# Booking engine
#  Netherlands
#
#
# Rakuten
# rakuten.co.jp
# 124
# 83
# E-commerce
#  Japan
#
#
# New York Times
# nytimes.com
# 127
# 80
# Newspaper
#  U.S.
#
#
# Alibaba Group
# alibaba.com
# 129
# 66
# E-commerce and Portal
#  China
#
#
# Bet365
# bet365.com
# 126
# 84
# Online gambling
#  U.K.
#
#
# eBay UK
# ebay.co.uk
# 139
# 83
# E-commerce
#  U.K.
#
#
# Quora
# quora.com
# 140
# 89
# Question and answer site
#  U.S.
#
#
# Avito.ru
# avito.ru
# 148
# 98
# E-commerce
#  Russia
#
#
# Google Vietnam
# google.com.vn
# 152
# 45
# Search engine
#  Vietnam
#
#
# Daily Mail
# dailymail.co.uk
# 162
# 86
# Tabloid news
#  U.K.
#
#
# Grupo Globo
# globo.com
# 163
# 56
# Search engine
#  Brazil
#
#
# Google Philippines
# google.com.ph
# 164
# 78
# Search engine
#  Philippines
#
#
# Google Colombia
# google.com.co
# 169
# 70
# Search engine
#  Colombia
#
#
# Universo Online
# uol.com.br
# 170
# 68
# Portal
#  Brazil
#
#
# Google Ukraine
# google.com.ua
# 181
# 63
# Search engine
#  Ukraine
#
#
# Nicovideo
# nicovideo.jp
# 188
# 88
# Video sharing
#  Japan
#
#
# Walmart
# walmart.com
# 214
# 95
# Retail stores and e-commerce
#  U.S.
#
#
# RedTube
# redtube.com
# 217
# 97
# Pornography
#  U.S.
#
#
# Go2Cloud
# go2cloud.org
# 242
# 73
# Cloud computing
#  India
#
#
# XNXX
# xnxx.com
# 258
# 31
# Pornography
#  France[5]
#
#
# AccuWeather
# accuweather.com
# 372
# 77
# Weather forecasting
#  U.S.
#
#
# Samsung
# samsung.com
# 396
# 82
# Technology
#  Korea
#
#
# Yahoo! Answers
# answers.yahoo.com
# N/A[notes 2]
# 67
# Question and answer site
#  U.S.
#
#
# Yahoo! News Japan
# news.yahoo.co.jp
# N/A[notes 2]
# 79
# News
#  Japan
#
#
# Google News
# news.google.com
# N/A[notes 2]
# 92
# News
#  U.S.
#
#
# None
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Wikipedia:WikiProject_Lists#Incomplete_lists
# //en.wikipedia.org/w/index.php?title=List_of_most_popular_websites&action=edit
# /wiki/Wikipedia:Identifying_reliable_sources
# /wiki/Website
# /wiki/Alexa_Internet
# //en.wikipedia.org/w/index.php?title=List_of_most_popular_websites&action=edit
# /wiki/SimilarWeb
# //en.wikipedia.org/w/index.php?title=List_of_most_popular_websites&action=edit
# #Ranking_measures
# #List_of_websites
# #References
# #Notes
# /wiki/Page_view
# #cite_note-ATR-1
# #cite_note-ATR-1
# /wiki/Internet
# /wiki/Internet_service_providers
# /wiki/Web_crawler
# #cite_note-2
# /wiki/Alexa_Internet
# //en.wikipedia.org/w/index.php?title=List_of_most_popular_websites&action=edit
# #cite_note-Alexa-3
# /wiki/SimilarWeb
# #cite_note-4
# /wiki/Google
# /wiki/Internet
# /wiki/United_States
# /wiki/United_States
# /wiki/YouTube
# /wiki/Video_hosting_service
# /wiki/United_States
# /wiki/United_States
# /wiki/Facebook
# /wiki/Social_networking_service
# /wiki/United_States
# /wiki/United_States
# /wiki/Baidu
# /wiki/Search_engine
# /wiki/China
# /wiki/China
# /wiki/Wikipedia
# /wiki/Online_encyclopedia
# /wiki/United_States
# /wiki/United_States
# /wiki/Yahoo!
# /wiki/Web_portal
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_engine
# /wiki/India
# /wiki/India
# /wiki/Reddit
# /wiki/Social_news
# /wiki/Entertainment
# /wiki/United_States
# /wiki/United_States
# /wiki/Tencent_QQ
# /wiki/Web_portal
# /wiki/China
# /wiki/China
# /wiki/Taobao
# /wiki/Online_shopping
# /wiki/China
# /wiki/China
# /wiki/Amazon.com
# /wiki/E-commerce
# /wiki/Cloud_computing
# /wiki/United_States
# /wiki/United_States
# /wiki/Tmall
# /wiki/Online_shopping
# /wiki/China
# /wiki/China
# /wiki/Twitter
# /wiki/Social_networking_service
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_engine
# /wiki/Japan
# /wiki/Japan
# /wiki/Sohu
# /wiki/Web_portal
# /wiki/China
# /wiki/China
# /wiki/Windows_Live
# /wiki/Software_plus_services
# /wiki/United_States
# /wiki/United_States
# /wiki/VK_(social_network)
# /wiki/Social_networking_service
# /wiki/Russia
# /wiki/Russia
# /wiki/Instagram
# /wiki/Photo_sharing
# /wiki/Social_media
# /wiki/United_States
# /wiki/United_States
# /wiki/Sina_Corp
# /wiki/Web_portal
# /wiki/Instant_messaging
# /wiki/China
# /wiki/China
# /wiki/360_Safeguard
# /wiki/Internet_security
# /wiki/Software
# /wiki/China
# /wiki/China
# /wiki/Google
# /wiki/Search_engine
# /wiki/Germany
# /wiki/Germany
# /wiki/JD.com
# /wiki/E-commerce
# /wiki/China
# /wiki/China
# /wiki/Google
# /wiki/Search_engine
# /wiki/United_Kingdom
# /wiki/UK
# /wiki/LinkedIn
# /wiki/Professional_network_service
# /wiki/Social_networking_service
# /wiki/United_States
# /wiki/United_States
# /wiki/Sina_Weibo
# /wiki/Social_networking_service
# /wiki/China
# /wiki/China
# /wiki/Google
# /wiki/Search_engine
# /wiki/France
# /wiki/France
# /wiki/Google
# /wiki/Search_engine
# /wiki/Russia
# /wiki/Russia
# /wiki/Google
# /wiki/Search_engine
# /wiki/Brazil
# /wiki/Brazil
# /wiki/Yahoo!_Japan
# /wiki/Web_portal
# /wiki/Japan
# /wiki/Japan
# /wiki/Yandex
# /wiki/Internet
# /wiki/Russia
# /wiki/Russia
# /wiki/Netflix
# /wiki/Streaming_media
# /wiki/Television_programs
# /wiki/Movies
# /wiki/United_States
# /wiki/United_States
# /wiki/T.co
# /wiki/URL_shortening
# /wiki/Twitter
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_engine
# /wiki/Hong_Kong
# /wiki/Hong_Kong
# /wiki/Hao123
# /wiki/Web_directories
# /wiki/China
# /wiki/China
# /wiki/Imgur
# /wiki/Image_hosting_service
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_engine
# /wiki/Italy
# /wiki/Italy
# /wiki/EBay
# /wiki/Online_auction
# /wiki/E-commerce
# /wiki/United_States
# /wiki/United_States
# /wiki/Pornhub
# /wiki/Pornography
# /wiki/Canada
# /wiki/Canada
# /wiki/Google
# /wiki/Search_engine
# /wiki/Spain
# /wiki/Spain
# /wiki/Tmall
# #cite_note-notsimilarweb-5
# /wiki/Online_shopping
# /wiki/China
# /wiki/China
# /wiki/WordPress.com
# /wiki/Blog
# /wiki/Social_media
# /wiki/United_States
# /wiki/United_States
# /wiki/MSN
# /wiki/Web_portal
# /wiki/United_States
# /wiki/United_States
# /wiki/AliExpress
# /wiki/Online_shopping
# /wiki/China
# /wiki/China
# /wiki/Bing_(search_engine)
# /wiki/Search_engine
# /wiki/United_States
# /wiki/United_States
# /wiki/Tumblr
# /wiki/Social_media
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_engine
# /wiki/Canada
# /wiki/Canada
# /wiki/LiveJasmin
# /wiki/Pornography
# /wiki/United_States
# /wiki/United_States
# /wiki/Microsoft
# /wiki/Software
# /wiki/Technology
# /wiki/United_States
# /wiki/United_States
# /wiki/Stack_Overflow
# /wiki/Question_and_answer_site
# /wiki/United_States
# /wiki/United_States
# /wiki/Twitch.tv
# /wiki/Streaming_media
# /wiki/Video_game
# /wiki/United_States
# /wiki/United_States
# /wiki/Soso.com
# /wiki/Search_engine
# /wiki/China
# /wiki/China
# /wiki/Blogspot
# /wiki/Blogging
# /wiki/United_States
# /wiki/United_States
# /wiki/Amazon.com
# /wiki/E-commerce
# /wiki/Japan
# /wiki/Japan
# /wiki/Odnoklassniki
# /wiki/Social_Networking
# /wiki/Russia
# /wiki/Russia
# /wiki/Google
# /wiki/Search_Engine
# /wiki/Mexico
# /wiki/Mexico
# /wiki/Apple_Inc.
# /wiki/Technology
# /wiki/Software
# /wiki/United_States
# /wiki/United_States
# /wiki/Naver
# /wiki/Web_portal
# /wiki/South_Korea
# /wiki/South_Korea
# /wiki/Mail.ru
# /wiki/Web_portal
# /wiki/Russia
# /wiki/Russia
# /wiki/IMDb
# /wiki/Film
# /wiki/Television_program
# /wiki/Video_game
# /wiki/United_States
# /wiki/United_States
# #cite_note-notsimilarweb-5
# /wiki/Pop-up_ad
# /wiki/Costa_Rica
# /wiki/Costa_Rica
# /wiki/Tianya_Club
# /wiki/Internet_forum
# /wiki/China
# /wiki/China
# /wiki/Microsoft_Office
# /wiki/Online_office_suite
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_Engine
# /wiki/South_Korea
# /wiki/Korea
# /wiki/GitHub
# /wiki/Source_code
# /wiki/United_States
# /wiki/United_States
# /wiki/Pinterest
# /wiki/Social_media
# /wiki/United_States
# /wiki/United_States
# /wiki/PayPal
# /wiki/E-commerce_payment_system
# /wiki/United_States
# /wiki/United_States
# /wiki/Diply
# /wiki/Canada
# /wiki/Canada
# /wiki/Google
# /wiki/Search_engine
# /wiki/Taiwan
# /wiki/Taiwan
# /wiki/Google
# /wiki/Search_engine
# /wiki/Turkey
# /wiki/Turkey
# /wiki/Google
# /wiki/Search_Engine
# /wiki/Australia
# /wiki/Australia
# /wiki/Amazon.com
# /wiki/E-commerce
# /wiki/Germany
# /wiki/Germany
# /wiki/Google
# /wiki/Search_engine
# /wiki/Indonesia
# /wiki/Indonesia
# /wiki/Microsoft_Online_Services
# /wiki/Software_as_a_service
# /wiki/United_States
# /wiki/United_States
# #cite_note-notsimilarweb-5
# /wiki/Online_advertising
# /wiki/United_States
# /wiki/United_States
# /wiki/Amazon.com
# /wiki/E-commerce
# /wiki/United_Kingdom
# /wiki/UK
# #cite_note-notsimilarweb-5
# /wiki/Pornography
# /wiki/United_States
# /wiki/United_States
# /wiki/Adobe_Systems
# /wiki/Software
# /wiki/United_States
# /wiki/United_States
# /wiki/Wikia
# /wiki/Wiki
# /wiki/United_States
# /wiki/United_States
# /wiki/Web_traffic
# /wiki/China
# /wiki/China
# /wiki/XHamster
# /wiki/Pornography
# /wiki/United_States
# /wiki/United_States
# /wiki/C%E1%BB%91c_C%E1%BB%91c
# /wiki/Search_engine
# /wiki/Web_browser
# /wiki/Vietnam
# /wiki/Vietnam
# /wiki/Bonga_Cams
# /wiki/Pornography
# /wiki/Russia
# /wiki/Russia
# /wiki/FC2_(portal)
# /wiki/Web_portal
# /wiki/Japan
# /wiki/Japan
# /wiki/Pixnet
# /wiki/Social_networking_service
# /wiki/Photo_sharing
# /wiki/Blog
# /wiki/Taiwan
# /wiki/Taiwan
# /wiki/Google
# /wiki/Search_engine
# /wiki/Poland
# /wiki/Poland
# /wiki/Dropbox_(service)
# /wiki/File_hosting_service
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# #cite_note-notsimilarweb-5
# /wiki/United_States
# /wiki/United_States
# /wiki/Guangming_Daily_(China)
# /wiki/Newspaper
# /wiki/China
# /wiki/China
# /wiki/WhatsApp
# /wiki/Instant_messaging
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_engine
# /wiki/Egypt
# /wiki/Egypt
# /wiki/Google
# /wiki/Search_engine
# /wiki/Thailand
# /wiki/Thailand
# /wiki/Google
# #cite_note-notsimilarweb-5
# /wiki/Search_engine
# /wiki/Saudi_Arabia
# /wiki/Saudi_Arabia
# /wiki/Amazon.com
# /wiki/E-commerce
# /wiki/India
# /wiki/India
# /wiki/Google
# /wiki/Search_engine
# /wiki/Argentina
# /wiki/Argentina
# /wiki/BBC
# /wiki/UK
# /wiki/Public_broadcasting
# /wiki/United_Kingdom
# /wiki/UK
# /wiki/Craigslist
# /wiki/Classified_advertising
# /wiki/United_States
# /wiki/United_States
# /wiki/BBC_Online
# /wiki/News
# /wiki/United_Kingdom
# /wiki/UK
# /wiki/Soundcloud
# /wiki/Streaming_media
# /wiki/United_States
# /wiki/United_States
# /wiki/Google
# /wiki/Search_engine
# /wiki/Netherlands
# /wiki/Netherlands
# /wiki/XVideos
# /wiki/Pornography
# /wiki/France
# /wiki/France
# /wiki/Booking.com
# /wiki/Booking_engine
# /wiki/Netherlands
# /wiki/Netherlands
# /wiki/Rakuten
# /wiki/E-commerce
# /wiki/Japan
# /wiki/Japan
# /wiki/New_York_Times
# /wiki/Newspaper
# /wiki/United_States
# /wiki/United_States
# /wiki/Alibaba_Group
# /wiki/E-commerce
# /wiki/Web_portal
# /wiki/China
# /wiki/China
# /wiki/Bet365
# /wiki/Online_gambling
# /wiki/United_Kingdom
# /wiki/U.K.
# /wiki/EBay
# /wiki/E-commerce
# /wiki/United_Kingdom
# /wiki/U.K.
# /wiki/Quora
# /wiki/Question_and_answer_site
# /wiki/United_States
# /wiki/United_States
# /wiki/Avito.ru
# /wiki/E-commerce
# /wiki/Russia
# /wiki/Russia
# /wiki/Google
# /wiki/Search_engine
# /wiki/Vietnam
# /wiki/Vietnam
# /wiki/Daily_Mail
# /wiki/Tabloid_(newspaper_format)
# /wiki/News
# /wiki/United_Kingdom
# /wiki/U.K.
# /wiki/Grupo_Globo
# /wiki/Search_engine
# /wiki/Brazil
# /wiki/Brazil
# /wiki/Google
# /wiki/Search_engine
# /wiki/Philippines
# /wiki/Google
# /wiki/Search_engine
# /wiki/Colombia
# /wiki/Colombia
# /wiki/Universo_Online
# /wiki/Web_portal
# /wiki/Brazil
# /wiki/Brazil
# /wiki/Google
# /wiki/Search_engine
# /wiki/Ukraine
# /wiki/Ukraine
# /wiki/Nicovideo
# /wiki/Video_sharing
# /wiki/Japan
# /wiki/Japan
# /wiki/Walmart
# /wiki/Retail_store
# /wiki/E-commerce
# /wiki/United_States
# /wiki/United_States
# /wiki/RedTube
# /wiki/Pornography
# /wiki/United_States
# /wiki/United_States
# /wiki/Cloud_computing
# /wiki/India
# /wiki/India
# /wiki/Pornography
# /wiki/France
# /wiki/France
# #cite_note-6
# /wiki/AccuWeather
# /wiki/Weather_forecasting
# /wiki/United_States
# /wiki/United_States
# /wiki/Samsung
# /wiki/Technology
# /wiki/South_Korea
# /wiki/South_Korea
# /wiki/Yahoo!_Answers
# #cite_note-notalexa-7
# /wiki/Question_and_answer_site
# /wiki/United_States
# /wiki/United_States
# /wiki/Yahoo!_Japan
# #cite_note-notalexa-7
# /wiki/News
# /wiki/Japan
# /wiki/Japan
# /wiki/Google_News
# #cite_note-notalexa-7
# /wiki/News
# /wiki/United_States
# /wiki/United_States
# #cite_ref-ATR_1-0
# #cite_ref-ATR_1-1
# https://support.alexa.com/hc/en-us/articles/200449744-How-are-Alexa-s-traffic-rankings-determined-
# /wiki/Alexa_Internet
# https://web.archive.org/web/20141129015307/https://support.alexa.com/hc/en-us/articles/200449744-How-are-Alexa-s-traffic-rankings-determined-
# #cite_ref-2
# http://www.similarweb.com/ourdata
# /wiki/SimilarWeb
# https://web.archive.org/web/20141202125632/http://www.similarweb.com/ourdata
# #cite_ref-Alexa_3-0
# http://www.alexa.com/topsites
# /wiki/Alexa_Internet
# https://web.archive.org/web/20150302173920/http://www.alexa.com/topsites
# #cite_ref-4
# https://pro.similarweb.com/#/industry/topsites/All/999/1m?webSource=Total
# /wiki/SimilarWeb
# https://web.archive.org/web/20160602070023/https://pro.similarweb.com/#/industry/topsites/All/999/1m?webSource=Total
# #cite_ref-6
# http://thenextweb.com/insider/2016/03/03/the-almost-invisible-men-and-women-behind-the-worlds-largest-porn-sites/
# https://web.archive.org/web/20160303215154/http://thenextweb.com/insider/2016/03/03/the-almost-invisible-men-and-women-behind-the-worlds-largest-porn-sites/
# #cite_ref-notsimilarweb_5-0
# #cite_ref-notsimilarweb_5-1
# #cite_ref-notsimilarweb_5-2
# #cite_ref-notsimilarweb_5-3
# #cite_ref-notsimilarweb_5-4
# #cite_ref-notsimilarweb_5-5
# #cite_ref-notalexa_7-0
# #cite_ref-notalexa_7-1
# #cite_ref-notalexa_7-2
# /wiki/File:Crystal_Clear_app_linneighborhood.svg
# /wiki/Portal:Internet
# /wiki/File:Text-x-generic.svg
# /wiki/Portal:Lists
# https://en.wikipedia.org/w/index.php?title=List_of_most_popular_websites&oldid=819467683
# /wiki/Help:Category
# /wiki/Category:Lists_of_Internet-related_superlatives
# /wiki/Category:Lists_of_websites
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Dynamic_lists
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_June_2017
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# /wiki/Category:Articles_containing_potentially_dated_statements_from_April_2017
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Articles_containing_potentially_dated_statements_from_May_2017
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=List+of+most+popular+websites
# /w/index.php?title=Special:UserLogin&returnto=List+of+most+popular+websites
# /wiki/List_of_most_popular_websites
# /wiki/Talk:List_of_most_popular_websites
# /wiki/List_of_most_popular_websites
# /w/index.php?title=List_of_most_popular_websites&action=edit
# /w/index.php?title=List_of_most_popular_websites&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Portal:Contents
# /wiki/Portal:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/List_of_most_popular_websites
# /wiki/Special:RecentChangesLinked/List_of_most_popular_websites
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=List_of_most_popular_websites&oldid=819467683
# /w/index.php?title=List_of_most_popular_websites&action=info
# https://www.wikidata.org/wiki/Special:EntityPage/Q6629082
# /w/index.php?title=Special:CiteThisPage&page=List_of_most_popular_websites&id=819467683
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=List+of+most+popular+websites
# /w/index.php?title=Special:ElectronPdf&page=List+of+most+popular+websites&action=show-download-screen
# /w/index.php?title=List_of_most_popular_websites&printable=yes
# https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D9%85%D9%88%D8%A7%D9%82%D8%B9_%D8%A7%D9%84%D8%A5%D9%86%D8%AA%D8%B1%D9%86%D8%AA_%D8%A7%D9%84%D8%A3%D9%83%D8%AB%D8%B1_%D8%B2%D9%8A%D8%A7%D8%B1%D8%A9
# https://bn.wikipedia.org/wiki/%E0%A6%B8%E0%A6%B0%E0%A7%8D%E0%A6%AC%E0%A6%BE%E0%A6%A7%E0%A6%BF%E0%A6%95_%E0%A6%9C%E0%A6%A8%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A6%BF%E0%A6%AF%E0%A6%BC_%E0%A6%93%E0%A6%AF%E0%A6%BC%E0%A7%87%E0%A6%AC%E0%A6%B8%E0%A6%BE%E0%A6%87%E0%A6%9F%E0%A6%B8%E0%A6%AE%E0%A7%82%E0%A6%B9%E0%A7%87%E0%A6%B0_%E0%A6%A4%E0%A6%BE%E0%A6%B2%E0%A6%BF%E0%A6%95%E0%A6%BE
# https://bcl.wikipedia.org/wiki/Lista_kan_Pinakapopular_na_mga_Websityo
# https://da.wikipedia.org/wiki/Liste_over_mest_popul%C3%A6re_websteder
# https://de.wikipedia.org/wiki/Liste_der_meistaufgerufenen_Websites
# https://es.wikipedia.org/wiki/Anexo:Sitios_web_m%C3%A1s_visitados
# https://hr.wikipedia.org/wiki/Popis_najpopularnijih_web_stranica
# https://id.wikipedia.org/wiki/Daftar_situs_web_terpopuler
# https://hu.wikipedia.org/wiki/A_legn%C3%A9pszer%C5%B1bb_weboldalak_list%C3%A1ja
# https://ja.wikipedia.org/wiki/%E4%BA%BA%E6%B0%97%E3%81%AE%E3%82%A6%E3%82%A7%E3%83%96%E3%82%B5%E3%82%A4%E3%83%88%E4%B8%80%E8%A6%A7
# https://pt.wikipedia.org/wiki/Lista_de_websites_mais_acessados
# https://tt.wikipedia.org/wiki/%D0%98%D2%A3_%D0%BF%D0%BE%D0%BF%D1%83%D0%BB%D1%8F%D1%80_%D0%B2%D0%B5%D0%B1-%D1%81%D0%B0%D0%B9%D1%82%D0%BB%D0%B0%D1%80_%D0%B8%D1%81%D0%B5%D0%BC%D0%BB%D0%B5%D0%B3%D0%B5
# https://tr.wikipedia.org/wiki/En_pop%C3%BCler_web_siteleri_listesi
# https://uk.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BD%D0%B0%D0%B9%D0%BF%D0%BE%D0%BF%D1%83%D0%BB%D1%8F%D1%80%D0%BD%D1%96%D1%88%D0%B8%D1%85_%D0%B2%D0%B5%D0%B1-%D1%81%D0%B0%D0%B9%D1%82%D1%96%D0%B2
# https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_nh%E1%BB%AFng_website_ph%E1%BB%95_bi%E1%BA%BFn_nh%E1%BA%A5t
# https://zh.wikipedia.org/wiki/%E6%9C%80%E5%8F%97%E6%AC%A2%E8%BF%8E%E7%BD%91%E7%AB%99%E5%88%97%E8%A1%A8
# https://www.wikidata.org/wiki/Special:EntityPage/Q6629082#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //wikimediafoundation.org/wiki/Terms_of_Use
# //wikimediafoundation.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://wikimediafoundation.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://wikimediafoundation.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=List_of_most_popular_websites&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# //www.mediawiki.org/
#
#
#
# List of most popular websites - Wikipedia
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_most_popular_websites","wgTitle":"List of most popular websites","wgCurRevisionId":819467683,"wgRevisionId":819467683,"wgArticleId":37716939,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia indefinitely semi-protected pages","Dynamic lists","Wikipedia articles in need of updating from June 2017","All Wikipedia articles in need of updating","Articles containing potentially dated statements from April 2017","All articles containing potentially dated statements","Articles containing potentially dated statements from May 2017","Lists of Internet-related superlatives","Lists of websites"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_most_popular_websites","wgRelevantArticleId":37716939,"wgRequestId":"WlcCkApAEKcAAGuSJqYAAABS","wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfirmed"],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFExpandAllSectionsUserOption":false,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q6629082","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/
#
# });mw.loader.load(["ext.cite.a11y","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# List of most popular websites
# From Wikipedia, the free encyclopedia
#
# 					Jump to:					navigation, 					search
#
# This is a dynamic list and may never be able to satisfy particular standards for completeness. You can help by expanding it with reliably sourced entries.
#
#
#
#
#
#
# This article needs to be updated. Please update this article to reflect recent events or newly available information. (June 2017)
#
#
#
# This is a list of the most popular websites worldwide according to the top 100 lists published by Alexa Internet, as of April 3, 2017,[update] and SimilarWeb, as of May 2017.[update]
#
#
#
# Contents
#
#
# 1 Ranking measures
# 2 List of websites
# 3 References
#
# 3.1 Notes
#
#
#
#
#
# Ranking measures
# Alexa ranks websites based on a combined measure of page views and unique site users, and creates a list of most popular websites based on this ranking time-averaged over three-month periods.[1] Only the site's highest-level domain is recorded, aggregating any subdomains.[1]
# SimilarWeb ranks websites based on a panel of millions of Internet users, International/U.S. internet service providers, direct measurement of web traffic from data from thousands of websites and web crawlers scanning public websites.[2]
# List of websites
#
#
# Site
# Domain
# Alexa top 100 global websites
# (As of April 3, 2017[update])[3]
# SimilarWeb top 100 websites
# (As of May 2017)[4]
# Type
#
# Principal country
#
#
#
# Google
# google.com
# 1
# 1
# Internet services and products
#  U.S.
#
#
# YouTube
# youtube.com
# 2
# 3
# Video sharing
#  U.S.
#
#
# Facebook
# facebook.com
# 3
# 2
# Social network
#  U.S.
#
#
# Baidu
# baidu.com
# 4
# 11
# Search engine
#  China
#
#
# Wikipedia
# wikipedia.org
# 5
# 5
# Encyclopedia
#  U.S.
#
#
# Yahoo!
# yahoo.com
# 6
# 4
# Portal and media
#  U.S.
#
#
# Google India
# google.co.in
# 7
# 8
# Search engine
#  India
#
#
# Reddit
# reddit.com
# 8
# 27
# Social news and entertainment
#  U.S.
#
#
# Tencent QQ
# qq.com
# 9
# 36
# Portal
#  China
#
#
# Taobao
# taobao.com
# 10
# 65
# Online shopping
#  China
#
#
# Amazon
# amazon.com
# 11
# 14
# E-commerce and cloud computing
#  U.S.
#
#
# Tmall
# tmall.com
# 12
# 74
# Online shopping
#  China
#
#
# Twitter
# twitter.com
# 13
# 6
# Social network
#  U.S.
#
#
# Google Japan
# google.co.jp
# 14
# 20
# Search engine
#  Japan
#
#
# Sohu
# sohu.com
# 15
# 204
# Portal
#  China
#
#
# Windows Live
# live.com
# 16
# 7
# Software plus services
#  U.S.
#
#
# VK
# vk.com
# 17
# 12
# Social network
#  Russia
#
#
# Instagram
# instagram.com
# 18
# 15
# Photo sharing and social media
#  U.S.
#
#
# Sina Corp
# sina.com.cn
# 19
# 110
# Portal and instant messaging
#  China
#
#
# 360 Safeguard
# 360.cn
# 20
# 85
# Internet security software
#  China
#
#
# Google Germany
# google.de
# 21
# 17
# Search engine
#  Germany
#
#
# Jingdong Mall
# jd.com
# 22
# 96
# E-commerce
#  China
#
#
# Google UK
# google.co.uk
# 23
# 10
# Search engine
#  UK
#
#
# LinkedIn
# linkedin.com
# 24
# 41
# Professional Social network
#  U.S.
#
#
# Sina Weibo
# weibo.com
# 25
# 81
# Social network
#  China
#
#
# Google France
# google.fr
# 26
# 19
# Search engine
#  France
#
#
# Google Russia
# google.ru
# 27
# 23
# Search engine
#  Russia
#
#
# Google Brazil
# google.com.br
# 28
# 8
# Search engine
#  Brazil
#
#
# Yahoo! Japan
# yahoo.co.jp
# 29
# 26
# Portal
#  Japan
#
#
# Yandex
# yandex.ru
# 30
# 13
# Internet services and products
#  Russia
#
#
# Netflix
# netflix.com
# 31
# 18
# Streaming TV and movies
#  U.S.
#
#
# t.co
# t.co
# 32
# 78
# URL shortening for links on Twitter
#  U.S.
#
#
# Google Hong Kong
# google.com.hk
# 33
# 138
# Search engine
#  Hong Kong
#
#
# Hao123
# hao123.com
# 34
# 180
# Web directories
#  China
#
#
# Imgur
# imgur.com
# 35
# 57
# Image sharing
#  U.S.
#
#
# Google Italy
# google.it
# 36
# 29
# Search engine
#  Italy
#
#
# eBay
# ebay.com
# 37
# 32
# Online auctions and shopping
#  U.S.
#
#
# Pornhub
# pornhub.com
# 38
# 24
# Pornography
#  Canada
#
#
# Google Spain
# google.es
# 39
# 35
# Search engine
#  Spain
#
#
# Tmall
# detail.tmall.com
# 40
# N/A[notes 1]
# Online shopping
#  China
#
#
# WordPress.com
# wordpress.com
# 41
# 43
# Blogging and social media websites
#  U.S.
#
#
# MSN
# msn.com
# 42
# 33
# Portal
#  U.S.
#
#
# AliExpress
# aliexpress.com
# 43
# 49
# Online shopping
#  China
#
#
# Bing
# bing.com
# 44
# 40
# Search engine
#  U.S.
#
#
# Tumblr
# tumblr.com
# 45
# 44
# Social media
#  U.S.
#
#
# Google Canada
# google.ca
# 46
# 25
# Search engine
#  Canada
#
#
# LiveJasmin
# livejasmin.com
# 47
# 196
# Pornography
#  U.S.
#
#
# Microsoft
# microsoft.com
# 48
# 47
# Software and technology
#  U.S.
#
#
# Stack Overflow
# stackoverflow.com
# 49
# 93
# Question and answer site
#  U.S.
#
#
# Twitch
# twitch.tv
# 50
# 76
# Streaming primarily video games
#  U.S.
#
#
# Soso.com
# soso.com
# 51
# 98,882
# Search engine
#  China
#
#
# Blogspot
# blogspot.com
# 52
# 450,370
# Blogging
#  U.S.
#
#
# Amazon Japan
# amazon.co.jp
# 53
# 71
# E-commerce
#  Japan
#
#
# Odnoklassniki
# ok.ru
# 54
# 28
# Social Networking
#  Russia
#
#
# Google Mexico
# google.com.mx
# 55
# 30
# Search Engine
#  Mexico
#
#
# Apple Inc.
# apple.com
# 56
# 67
# Technology and software
#  U.S.
#
#
# Naver
# Naver.com
# 57
# 59
# Portal
#  Korea
#
#
# Mail.ru
# mail.ru
# 58
# 16
# Portal
#  Russia
#
#
# IMDb
# imdb.com
# 59
# 51
# Film, TV show, and video game database
#  U.S.
#
#
# PopAds
# popads.net
# 60
# N/A[notes 1]
# Pop-up advertising
#  Costa Rica
#
#
# Tianya Club
# tianya.cn
# 61
# 730
# Internet forum
#  China
#
#
# Microsoft Office
# office.com
# 62
# 48
# Online office suite
#  U.S.
#
#
# Google Korea
# google.co.kr
# 63
# 177
# Search Engine
#  Korea
#
#
# GitHub
# github.com
# 64
# 74
# Source code hosting service
#  U.S.
#
#
# Pinterest
# pinterest.com
# 65
# 39
# Social media
#  U.S.
#
#
# PayPal
# paypal.com
# 66
# 64
# Payment system
#  U.S.
#
#
# Diply
# diply.com
# 67
# 588
# Entertainment
#  Canada
#
#
# Google Taiwan
# google.com.tw
# 68
# 81
# Search engine
#  Taiwan
#
#
# Google Turkey
# google.com.tr
# 69
# 22
# Search engine
#  Turkey
#
#
# Google Australia
# google.com.au
# 70
# 42
# Search Engine
#  Australia
#
#
# Amazon Germany
# amazon.de
# 72
# 75
# E-commerce
#  Germany
#
#
# Google Indonesia
# google.co.id
# 73
# 38
# Search engine
#  Indonesia
#
#
# Microsoft Online Services
# microsoftonline.com
# 74
# 60
# Software as a service
#  U.S.
#
#
# Onclckds
# onclckds.com
# 75
# N/A[notes 1]
# Online advertising network
#  U.S.
#
#
# Amazon UK
# amazon.co.uk
# 76
# 76
# E-commerce
#  UK
#
#
# TXXX
# txxx.com
# 77
# N/A[notes 1]
# Pornography
#  U.S.
#
#
# Adobe Systems
# adobe.com
# 78
# 94
# Software
#  U.S.
#
#
# Wikia
# wikia.com
# 79
# 66
# Wikis
#  U.S.
#
#
# CNZZ
# cnzz.com
# 80
# 42,424
# Web traffic statistics
#  China
#
#
# xHamster
# xhamster.com
# 81
# 46
# Pornography
#  U.S.
#
#
# Cốc Cốc
# coccoc.com
# 82
# 342
# Search engine and web browser
#  Vietnam
#
#
# Bonga Cams
# bongacams.com
# 83
# 230
# Pornography
#  Russia
#
#
# FC2
# fc2.com
# 84
# 82
# Portal
#  Japan
#
#
# Pixnet
# pixnet.net
# 85
# 322
# Social network, photo sharing, blogging
#  Taiwan
#
#
# Google Poland
# google.pl
# 86
# 37
# Search engine
#  Poland
#
#
# Dropbox
# dropbox.com
# 87
# 72
# File hosting service
#  U.S.
#
#
# Google file storage
# googleusercontent.com
# 88
# N/A[notes 1]
# File hosting service
#  U.S.
#
#
# Guangming Daily
# gmw.cn
# 89
# 15,520
# Newspaper
#  China
#
#
# WhatsApp
# whatsapp.com
# 91
# 34
# Instant messaging
#  U.S.
#
#
# Google Egypt
# google.com.eg
# 93
# 87
# Search engine
#  Egypt
#
#
# Google Thailand
# google.co.th
# 94
# 62
# Search engine
#  Thailand
#
#
# Google Saudi Arabia
# google.com.sa
# 95
# N/A[notes 1]
# Search engine
#  Saudi Arabia
#
#
# Amazon India
# amazon.in
# 98
# 121
# E-commerce
#  India
#
#
# Google Argentina
# google.com.ar
# 101
# 53
# Search engine
#  Argentina
#
#
# BBC
# bbc.co.uk
# 104
# 55
# UK public broadcasting
#  UK
#
#
# Craigslist
# craigslist.org
# 105
# 52
# Classified advertising
#  U.S.
#
#
# BBC Online
# bbc.com
# 109
# 89
# Global News
#  UK
#
#
# Soundcloud
# soundcloud.com
# 112
# 94
# Streaming media
#  U.S.
#
#
# Google Netherlands
# google.nl
# 113
# 54
# Search engine
#  Netherlands
#
#
# XVideos
# xvideos.com
# 117
# 21
# Pornography
#  France
#
#
# Booking.com
# booking.com
# 123
# 73
# Booking engine
#  Netherlands
#
#
# Rakuten
# rakuten.co.jp
# 124
# 83
# E-commerce
#  Japan
#
#
# New York Times
# nytimes.com
# 127
# 80
# Newspaper
#  U.S.
#
#
# Alibaba Group
# alibaba.com
# 129
# 66
# E-commerce and Portal
#  China
#
#
# Bet365
# bet365.com
# 126
# 84
# Online gambling
#  U.K.
#
#
# eBay UK
# ebay.co.uk
# 139
# 83
# E-commerce
#  U.K.
#
#
# Quora
# quora.com
# 140
# 89
# Question and answer site
#  U.S.
#
#
# Avito.ru
# avito.ru
# 148
# 98
# E-commerce
#  Russia
#
#
# Google Vietnam
# google.com.vn
# 152
# 45
# Search engine
#  Vietnam
#
#
# Daily Mail
# dailymail.co.uk
# 162
# 86
# Tabloid news
#  U.K.
#
#
# Grupo Globo
# globo.com
# 163
# 56
# Search engine
#  Brazil
#
#
# Google Philippines
# google.com.ph
# 164
# 78
# Search engine
#  Philippines
#
#
# Google Colombia
# google.com.co
# 169
# 70
# Search engine
#  Colombia
#
#
# Universo Online
# uol.com.br
# 170
# 68
# Portal
#  Brazil
#
#
# Google Ukraine
# google.com.ua
# 181
# 63
# Search engine
#  Ukraine
#
#
# Nicovideo
# nicovideo.jp
# 188
# 88
# Video sharing
#  Japan
#
#
# Walmart
# walmart.com
# 214
# 95
# Retail stores and e-commerce
#  U.S.
#
#
# RedTube
# redtube.com
# 217
# 97
# Pornography
#  U.S.
#
#
# Go2Cloud
# go2cloud.org
# 242
# 73
# Cloud computing
#  India
#
#
# XNXX
# xnxx.com
# 258
# 31
# Pornography
#  France[5]
#
#
# AccuWeather
# accuweather.com
# 372
# 77
# Weather forecasting
#  U.S.
#
#
# Samsung
# samsung.com
# 396
# 82
# Technology
#  Korea
#
#
# Yahoo! Answers
# answers.yahoo.com
# N/A[notes 2]
# 67
# Question and answer site
#  U.S.
#
#
# Yahoo! News Japan
# news.yahoo.co.jp
# N/A[notes 2]
# 79
# News
#  Japan
#
#
# Google News
# news.google.com
# N/A[notes 2]
# 92
# News
#  U.S.
#
#
# References
#
#
#
# ^ a b "How are Alexa's traffic rankings determined?". Alexa Internet. Archived from the original on November 29, 2014. Retrieved November 14, 2014.
# ^ "Compare Websites Traffic with SimilarWeb Analytics Tool". SimilarWeb. Archived from the original on December 2, 2014. Retrieved December 5, 2014.
# ^ "Alexa Top 500 Global Sites". Alexa Internet. Archived from the original on March 2, 2015. Retrieved April 3, 2017.
# ^ "Top Websites May 2017 All Traffic". SimilarWeb. Archived from the original on June 2, 2016. Retrieved June 30, 2017.
# ^ Woods, Ben (March 3, 2016). "The (almost) invisible men and women behind the world's largest porn sites". The Next Web. Archived from the original on March 3, 2016. Retrieved September 4, 2014.
#
#
#
# Notes
#
#
#
# ^ a b c d e f No SimilarWeb rating
# ^ a b c Alexa does not index subdomains, so it has no separate ranking for this website.
#
#
#
#
#
# Internet portal
# Lists portal
#
#
#
#
#
#
#
# 						Retrieved from "https://en.wikipedia.org/w/index.php?title=List_of_most_popular_websites&oldid=819467683"
# Categories: Lists of Internet-related superlativesLists of websitesHidden categories: Wikipedia indefinitely semi-protected pagesDynamic listsWikipedia articles in need of updating from June 2017All Wikipedia articles in need of updatingArticles containing potentially dated statements from April 2017All articles containing potentially dated statementsArticles containing potentially dated statements from May 2017
#
#
#
# Navigation menu
#
#
# Personal tools
#
# Not logged inTalkContributionsCreate accountLog in
#
#
#
# Namespaces
#
# ArticleTalk
#
#
#
# Variants
#
#
#
#
#
#
#
#
#
# Views
#
# ReadView sourceView history
#
#
# More
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
# Main pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store
#
#
#
# Interaction
#
#
# HelpAbout WikipediaCommunity portalRecent changesContact page
#
#
#
# Tools
#
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationWikidata itemCite this page
#
#
#
# Print/export
#
#
# Create a bookDownload as PDFPrintable version
#
#
#
# Languages
#
#
# العربيةবাংলাBikol CentralDanskDeutschEspañolHrvatskiBahasa IndonesiaMagyar日本語PortuguêsТатарча/tatarçaTürkçeУкраїнськаTiếng Việt中文
# Edit links
#
#
#
#
#
#  This page was last edited on 9 January 2018, at 15:00.
# Text is available under the Creative Commons Attribution-ShareAlike License;
# additional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.
#
#
# Privacy policy
# About Wikipedia
# Disclaimers
# Contact Wikipedia
# Developers
# Cookie statement
# Mobile view
#
#
#
#
#
#
#
#
#
# (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.424","walltime":"0.591","ppvisitednodes":{"value":10522,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":66851,"limit":2097152},"templateargumentsize":{"value":13103,"limit":2097152},"expansiondepth":{"value":20,"limit":40},"expensivefunctioncount":{"value":6,"limit":500},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  377.305      1 -total"," 40.24%  151.822    124 Template:Flagicon"," 21.57%   81.399      2 Template:Reflist"," 14.99%   56.547      4 Template:Cite_web"," 12.00%   45.262      1 Template:Pp-semi-indef","  9.04%   34.099    124 Template:Flagicon/core","  8.89%   33.541      1 Template:Update","  7.48%   28.236      3 Template:Main_other","  6.96%   26.270      1 Template:Ambox","  6.45%   24.336     48 Template:Country_data_USA"]},"scribunto":{"limitreport-timeusage":{"value":"0.088","limit":"10.000"},"limitreport-memusage":{"value":3189843,"limit":52428800}},"cachereport":{"origin":"mw1321","timestamp":"20180111062148","ttl":1900800,"transientcontent":false}}});});(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":74,"wgHostname":"mw1212"});});
#
#
#
# nav: None
#
#
# Site
# Domain
# Alexa top 100 global websites
# (As of April 3, 2017[update])[3]
# SimilarWeb top 100 websites
# (As of May 2017)[4]
# Type
#
# Principal country
#
#
#
# Google
# google.com
# 1
# 1
# Internet services and products
#  U.S.
#
#
# YouTube
# youtube.com
# 2
# 3
# Video sharing
#  U.S.
#
#
# Facebook
# facebook.com
# 3
# 2
# Social network
#  U.S.
#
#
# Baidu
# baidu.com
# 4
# 11
# Search engine
#  China
#
#
# Wikipedia
# wikipedia.org
# 5
# 5
# Encyclopedia
#  U.S.
#
#
# Yahoo!
# yahoo.com
# 6
# 4
# Portal and media
#  U.S.
#
#
# Google India
# google.co.in
# 7
# 8
# Search engine
#  India
#
#
# Reddit
# reddit.com
# 8
# 27
# Social news and entertainment
#  U.S.
#
#
# Tencent QQ
# qq.com
# 9
# 36
# Portal
#  China
#
#
# Taobao
# taobao.com
# 10
# 65
# Online shopping
#  China
#
#
# Amazon
# amazon.com
# 11
# 14
# E-commerce and cloud computing
#  U.S.
#
#
# Tmall
# tmall.com
# 12
# 74
# Online shopping
#  China
#
#
# Twitter
# twitter.com
# 13
# 6
# Social network
#  U.S.
#
#
# Google Japan
# google.co.jp
# 14
# 20
# Search engine
#  Japan
#
#
# Sohu
# sohu.com
# 15
# 204
# Portal
#  China
#
#
# Windows Live
# live.com
# 16
# 7
# Software plus services
#  U.S.
#
#
# VK
# vk.com
# 17
# 12
# Social network
#  Russia
#
#
# Instagram
# instagram.com
# 18
# 15
# Photo sharing and social media
#  U.S.
#
#
# Sina Corp
# sina.com.cn
# 19
# 110
# Portal and instant messaging
#  China
#
#
# 360 Safeguard
# 360.cn
# 20
# 85
# Internet security software
#  China
#
#
# Google Germany
# google.de
# 21
# 17
# Search engine
#  Germany
#
#
# Jingdong Mall
# jd.com
# 22
# 96
# E-commerce
#  China
#
#
# Google UK
# google.co.uk
# 23
# 10
# Search engine
#  UK
#
#
# LinkedIn
# linkedin.com
# 24
# 41
# Professional Social network
#  U.S.
#
#
# Sina Weibo
# weibo.com
# 25
# 81
# Social network
#  China
#
#
# Google France
# google.fr
# 26
# 19
# Search engine
#  France
#
#
# Google Russia
# google.ru
# 27
# 23
# Search engine
#  Russia
#
#
# Google Brazil
# google.com.br
# 28
# 8
# Search engine
#  Brazil
#
#
# Yahoo! Japan
# yahoo.co.jp
# 29
# 26
# Portal
#  Japan
#
#
# Yandex
# yandex.ru
# 30
# 13
# Internet services and products
#  Russia
#
#
# Netflix
# netflix.com
# 31
# 18
# Streaming TV and movies
#  U.S.
#
#
# t.co
# t.co
# 32
# 78
# URL shortening for links on Twitter
#  U.S.
#
#
# Google Hong Kong
# google.com.hk
# 33
# 138
# Search engine
#  Hong Kong
#
#
# Hao123
# hao123.com
# 34
# 180
# Web directories
#  China
#
#
# Imgur
# imgur.com
# 35
# 57
# Image sharing
#  U.S.
#
#
# Google Italy
# google.it
# 36
# 29
# Search engine
#  Italy
#
#
# eBay
# ebay.com
# 37
# 32
# Online auctions and shopping
#  U.S.
#
#
# Pornhub
# pornhub.com
# 38
# 24
# Pornography
#  Canada
#
#
# Google Spain
# google.es
# 39
# 35
# Search engine
#  Spain
#
#
# Tmall
# detail.tmall.com
# 40
# N/A[notes 1]
# Online shopping
#  China
#
#
# WordPress.com
# wordpress.com
# 41
# 43
# Blogging and social media websites
#  U.S.
#
#
# MSN
# msn.com
# 42
# 33
# Portal
#  U.S.
#
#
# AliExpress
# aliexpress.com
# 43
# 49
# Online shopping
#  China
#
#
# Bing
# bing.com
# 44
# 40
# Search engine
#  U.S.
#
#
# Tumblr
# tumblr.com
# 45
# 44
# Social media
#  U.S.
#
#
# Google Canada
# google.ca
# 46
# 25
# Search engine
#  Canada
#
#
# LiveJasmin
# livejasmin.com
# 47
# 196
# Pornography
#  U.S.
#
#
# Microsoft
# microsoft.com
# 48
# 47
# Software and technology
#  U.S.
#
#
# Stack Overflow
# stackoverflow.com
# 49
# 93
# Question and answer site
#  U.S.
#
#
# Twitch
# twitch.tv
# 50
# 76
# Streaming primarily video games
#  U.S.
#
#
# Soso.com
# soso.com
# 51
# 98,882
# Search engine
#  China
#
#
# Blogspot
# blogspot.com
# 52
# 450,370
# Blogging
#  U.S.
#
#
# Amazon Japan
# amazon.co.jp
# 53
# 71
# E-commerce
#  Japan
#
#
# Odnoklassniki
# ok.ru
# 54
# 28
# Social Networking
#  Russia
#
#
# Google Mexico
# google.com.mx
# 55
# 30
# Search Engine
#  Mexico
#
#
# Apple Inc.
# apple.com
# 56
# 67
# Technology and software
#  U.S.
#
#
# Naver
# Naver.com
# 57
# 59
# Portal
#  Korea
#
#
# Mail.ru
# mail.ru
# 58
# 16
# Portal
#  Russia
#
#
# IMDb
# imdb.com
# 59
# 51
# Film, TV show, and video game database
#  U.S.
#
#
# PopAds
# popads.net
# 60
# N/A[notes 1]
# Pop-up advertising
#  Costa Rica
#
#
# Tianya Club
# tianya.cn
# 61
# 730
# Internet forum
#  China
#
#
# Microsoft Office
# office.com
# 62
# 48
# Online office suite
#  U.S.
#
#
# Google Korea
# google.co.kr
# 63
# 177
# Search Engine
#  Korea
#
#
# GitHub
# github.com
# 64
# 74
# Source code hosting service
#  U.S.
#
#
# Pinterest
# pinterest.com
# 65
# 39
# Social media
#  U.S.
#
#
# PayPal
# paypal.com
# 66
# 64
# Payment system
#  U.S.
#
#
# Diply
# diply.com
# 67
# 588
# Entertainment
#  Canada
#
#
# Google Taiwan
# google.com.tw
# 68
# 81
# Search engine
#  Taiwan
#
#
# Google Turkey
# google.com.tr
# 69
# 22
# Search engine
#  Turkey
#
#
# Google Australia
# google.com.au
# 70
# 42
# Search Engine
#  Australia
#
#
# Amazon Germany
# amazon.de
# 72
# 75
# E-commerce
#  Germany
#
#
# Google Indonesia
# google.co.id
# 73
# 38
# Search engine
#  Indonesia
#
#
# Microsoft Online Services
# microsoftonline.com
# 74
# 60
# Software as a service
#  U.S.
#
#
# Onclckds
# onclckds.com
# 75
# N/A[notes 1]
# Online advertising network
#  U.S.
#
#
# Amazon UK
# amazon.co.uk
# 76
# 76
# E-commerce
#  UK
#
#
# TXXX
# txxx.com
# 77
# N/A[notes 1]
# Pornography
#  U.S.
#
#
# Adobe Systems
# adobe.com
# 78
# 94
# Software
#  U.S.
#
#
# Wikia
# wikia.com
# 79
# 66
# Wikis
#  U.S.
#
#
# CNZZ
# cnzz.com
# 80
# 42,424
# Web traffic statistics
#  China
#
#
# xHamster
# xhamster.com
# 81
# 46
# Pornography
#  U.S.
#
#
# Cốc Cốc
# coccoc.com
# 82
# 342
# Search engine and web browser
#  Vietnam
#
#
# Bonga Cams
# bongacams.com
# 83
# 230
# Pornography
#  Russia
#
#
# FC2
# fc2.com
# 84
# 82
# Portal
#  Japan
#
#
# Pixnet
# pixnet.net
# 85
# 322
# Social network, photo sharing, blogging
#  Taiwan
#
#
# Google Poland
# google.pl
# 86
# 37
# Search engine
#  Poland
#
#
# Dropbox
# dropbox.com
# 87
# 72
# File hosting service
#  U.S.
#
#
# Google file storage
# googleusercontent.com
# 88
# N/A[notes 1]
# File hosting service
#  U.S.
#
#
# Guangming Daily
# gmw.cn
# 89
# 15,520
# Newspaper
#  China
#
#
# WhatsApp
# whatsapp.com
# 91
# 34
# Instant messaging
#  U.S.
#
#
# Google Egypt
# google.com.eg
# 93
# 87
# Search engine
#  Egypt
#
#
# Google Thailand
# google.co.th
# 94
# 62
# Search engine
#  Thailand
#
#
# Google Saudi Arabia
# google.com.sa
# 95
# N/A[notes 1]
# Search engine
#  Saudi Arabia
#
#
# Amazon India
# amazon.in
# 98
# 121
# E-commerce
#  India
#
#
# Google Argentina
# google.com.ar
# 101
# 53
# Search engine
#  Argentina
#
#
# BBC
# bbc.co.uk
# 104
# 55
# UK public broadcasting
#  UK
#
#
# Craigslist
# craigslist.org
# 105
# 52
# Classified advertising
#  U.S.
#
#
# BBC Online
# bbc.com
# 109
# 89
# Global News
#  UK
#
#
# Soundcloud
# soundcloud.com
# 112
# 94
# Streaming media
#  U.S.
#
#
# Google Netherlands
# google.nl
# 113
# 54
# Search engine
#  Netherlands
#
#
# XVideos
# xvideos.com
# 117
# 21
# Pornography
#  France
#
#
# Booking.com
# booking.com
# 123
# 73
# Booking engine
#  Netherlands
#
#
# Rakuten
# rakuten.co.jp
# 124
# 83
# E-commerce
#  Japan
#
#
# New York Times
# nytimes.com
# 127
# 80
# Newspaper
#  U.S.
#
#
# Alibaba Group
# alibaba.com
# 129
# 66
# E-commerce and Portal
#  China
#
#
# Bet365
# bet365.com
# 126
# 84
# Online gambling
#  U.K.
#
#
# eBay UK
# ebay.co.uk
# 139
# 83
# E-commerce
#  U.K.
#
#
# Quora
# quora.com
# 140
# 89
# Question and answer site
#  U.S.
#
#
# Avito.ru
# avito.ru
# 148
# 98
# E-commerce
#  Russia
#
#
# Google Vietnam
# google.com.vn
# 152
# 45
# Search engine
#  Vietnam
#
#
# Daily Mail
# dailymail.co.uk
# 162
# 86
# Tabloid news
#  U.K.
#
#
# Grupo Globo
# globo.com
# 163
# 56
# Search engine
#  Brazil
#
#
# Google Philippines
# google.com.ph
# 164
# 78
# Search engine
#  Philippines
#
#
# Google Colombia
# google.com.co
# 169
# 70
# Search engine
#  Colombia
#
#
# Universo Online
# uol.com.br
# 170
# 68
# Portal
#  Brazil
#
#
# Google Ukraine
# google.com.ua
# 181
# 63
# Search engine
#  Ukraine
#
#
# Nicovideo
# nicovideo.jp
# 188
# 88
# Video sharing
#  Japan
#
#
# Walmart
# walmart.com
# 214
# 95
# Retail stores and e-commerce
#  U.S.
#
#
# RedTube
# redtube.com
# 217
# 97
# Pornography
#  U.S.
#
#
# Go2Cloud
# go2cloud.org
# 242
# 73
# Cloud computing
#  India
#
#
# XNXX
# xnxx.com
# 258
# 31
# Pornography
#  France[5]
#
#
# AccuWeather
# accuweather.com
# 372
# 77
# Weather forecasting
#  U.S.
#
#
# Samsung
# samsung.com
# 396
# 82
# Technology
#  Korea
#
#
# Yahoo! Answers
# answers.yahoo.com
# N/A[notes 2]
# 67
# Question and answer site
#  U.S.
#
#
# Yahoo! News Japan
# news.yahoo.co.jp
# N/A[notes 2]
# 79
# News
#  Japan
#
#
# Google News
# news.google.com
# N/A[notes 2]
# 92
# News
#  U.S.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7a139fa476a2> in <module>()
#      30             print(table.text)
#      31             tbody = table.find('tbody')
# ---> 32             tr_rows = tbody.find_all('tr')
#      33             for tr in tr_rows:
#      34                 td = tr.find_all('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# # 1.3.gPRC  & Protocol Bufferes
# gPRC a client application can direcly call methods on a server application on a different machine as if it was a local object.
# By default gPRC uses protocol buffers (serializing structured data 序列化结构化数据)
#
# ### Install gPRC
#     $ python3 -m pip install grpcio
#
#     $ python3 -m pip install grpcio-tools # install gPRC tools
#
# ### Google's gRPC provides a framework for implementing RPC (Remote Procedure Call) workflows. By layerinmg on top HTTP/2 and using protocol buffers,gRPC promises a lot of benefits over conventional REST+JSON APIs

# %% [markdown]
# # Coroutine 协程,微线程,是一种用户态的轻量级线程{协程拥有自己的寄存器上下文和栈,无法利用多核心的资源,协程本质上是单线程,协程需要和进程配合才能运行在多CPU.堵塞Blocking}

# %%
# yield 实现协程操作
import time 
import queue 

def consumer(name):
    print("--->starting eating food...")
    while True:
        new_food = yield
        print("[%s] is eating food %s" %(name, new_food))

def producer():
    
    r = con.__next__()
    r = con2.__next__()
    n = 0 
    while n < 5:
        n +=1
        con.send(n)
        con2.send(n)
        print("\033[32;1m[producer]\033[0m is making food %s]]")

# %% [markdown]
# # 7 tips to Time Python scripts and control Memory & CPU usage

# %%
# Tools to detect the bottlenecks of your code
# 1. Use a decorator to time your functions
import time 
from functools import wraps

def fn_timer(function):
    @wraps(function)
    def function_timer(*args, **kwargs):
        t0 = time.time()
        result = function(*args, **kwargs)
        t1 = time.time()
        print("Total time runing [ {:^20s} ] :: [{:^10s} seconds]".format(function.__name__, str(round(t1-t0,4))))
        return result
    return function_timer 
@fn_timer
def test():
    for i in range(100):
        time.sleep(.1)

if __name__ == '__main__':
        
    test()
# Out:
# Total time runing [         test         ] :: [      10.0595        seconds]

# %% [markdown]
# # Python 计算时间差

# %%
import datetime 
end = datetime.datetime(2018,1,9)
start = datetime.datetime(2005,4,1)
(end-start).days
(datetime.datetime(2018,1,22) - datetime.datetime(1993,2,1)).days
# Out:
# 9121

# %% [markdown]
# # Pandas 教程

# %%
# Dataframe 数据选取和过滤

import pandas as pd 
import numpy as np 
df = pd.DataFrame(np.random.randn(6,4), columns=list('ABCD'))

# 选取 一列或多列
print(df['A'])
print(df[['A','B']])

# 选取一行或几行
print(df.iloc[1,:])
print(df.iloc[1:3,:])

# loc 通过行标签选取数据
print(df.loc[:,'A'])

# iloc, 通过行号获取数据
print(df.iloc[1])

# iat, 获取某一个cell值
print(df.iat[1,2])

# [] 过滤, 筛选D列数据中大于0行; []表示一个boolean表达式
df[df.D>0.5]
print(df[df>1])

# apply 方法构造复杂过滤,实现将返回值为boolean的方法作为过滤条件
print(df[df.apply(lambda x: x['B'] > x['C'], axis=1)])

# & 符号可以实现多条件筛选,"|"实现多条件或
df[(df.D>0) & (df.C<0)]
# 只需要A和B列数据,而D和C列数据都是用于筛选
df[['A','B']][(df.D>0)&(df.C<0)]
# 通过布尔索引
index = (df.D>0) & (df.C<0)
df[index]
# Out:
# 0   -0.480369
# 1   -0.220118
# 2    0.518165
# 3    0.787031
# 4    0.825968
# 5   -0.099401
# Name: A, dtype: float64
#           A         B
# 0 -0.480369  0.657884
# 1 -0.220118  0.914549
# 2  0.518165 -1.136548
# 3  0.787031  0.660821
# 4  0.825968  0.637076
# 5 -0.099401 -0.761609
# A   -0.220118
# B    0.914549
# C   -0.505112
# D    0.729200
# Name: 1, dtype: float64
#           A         B         C         D
# 1 -0.220118  0.914549 -0.505112  0.729200
# 2  0.518165 -1.136548  0.587791 -0.810353
# 0   -0.480369
# 1   -0.220118
# 2    0.518165
# 3    0.787031
# 4    0.825968
# 5   -0.099401
# Name: A, dtype: float64
# A   -0.220118
# B    0.914549
# C   -0.505112
# D    0.729200
# Name: 1, dtype: float64
# -0.5051117572442305
#     A   B         C   D
# 0 NaN NaN       NaN NaN
# 1 NaN NaN       NaN NaN
# 2 NaN NaN       NaN NaN
# 3 NaN NaN       NaN NaN
# 4 NaN NaN       NaN NaN
# 5 NaN NaN  2.749369 NaN
#           A         B         C         D
# 0 -0.480369  0.657884 -0.745022  0.819480
# 1 -0.220118  0.914549 -0.505112  0.729200
# 3  0.787031  0.660821 -0.842835 -0.207633
# 4  0.825968  0.637076  0.182801 -0.731794
#           A         B         C        D
# 0 -0.480369  0.657884 -0.745022  0.81948
# 1 -0.220118  0.914549 -0.505112  0.72920

# %% [markdown]
# # 贝叶斯

# %%
"""
# 联合概率满足交换律
P(A and B) = P(B and A)

# 联合概率以条件概率展开
P(A and B) = P(A) P(B|A)
P(B and A) = P(B) P(A|B)
P(A) P(B|A) = P(B) P(A|B)

# 变化得到
P(B|A) = P(A|B)P(B)/P(A)

P(B) : 先验概率,得到新数据前某一假设的概率
P(B|A): 后验概率,观察到新数据后计算假设的概率
P(A|B):似然度,既在该假设下得到的这一数据的概率
P(A): 标准化常量,在任何假设下得到这一数据的概率

"""
